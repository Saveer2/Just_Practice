# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("titanic_cleaned.csv")

# Clean column names
df.columns = df.columns.str.strip().str.lower()

# Select numeric columns for correlation
num_cols = ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']
corr_matrix = df[num_cols].corr()

print("Correlation Matrix:\n", corr_matrix)

# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Titanic Dataset")
plt.show()
# Out:
# Correlation Matrix:
#            survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.244686 -0.055862 -0.014375  0.054908  0.173786
# pclass   -0.244686  1.000000 -0.377908  0.060832  0.018322 -0.558683
# age      -0.055862 -0.377908  1.000000 -0.189972 -0.125851  0.178182
# sibsp    -0.014375  0.060832 -0.189972  1.000000  0.373587  0.160349
# parch     0.054908  0.018322 -0.125851  0.373587  1.000000  0.221635
# fare      0.173786 -0.558683  0.178182  0.160349  0.221635  1.000000
